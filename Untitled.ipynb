# %%
import pandas as pd
import numpy as np
import panel as pn
import holoviews as hv

from geopy import geocoders

# %% [markdown]
# <h2> Importing Data </h2>

# %%
df = pd.read_csv("/Users/viktoriasasvari/Data Science/layoffs.csv")
df = df.fillna(0)
df
# Out:
#             company        location        industry  total_laid_off  \
# 0             Lemon    Buenos Aires          Crypto             0.0
# 1            Assure  Salt Lake City         Finance             0.0
# 2          GoodGood         Toronto          Retail             0.0
# 3            SIRCLO         Jakarta          Retail           160.0
# 4              Trax       Singapore          Retail            80.0
# ...             ...             ...             ...             ...
# 1660        Service     Los Angeles          Travel             0.0
# 1661   HopSkipDrive     Los Angeles  Transportation             8.0
# 1662    Panda Squad     SF Bay Area        Consumer             6.0
# 1663  Tamara Mellon     Los Angeles          Retail            20.0
# 1664       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %% [markdown]
# <h2> Companies with most layoffs </h2>

# %%
sample = df[['company', 'total_laid_off']]
df2 = sample.groupby(['company']).sum() # adding together duplicate rows
Sorted = df2.sort_values( # highest to lowest
    by="total_laid_off",
    ascending=False
)
Sorted.head(11)
# Out:
#              total_laid_off
# company
# Meta                11000.0
# Amazon              10000.0
# Uber                 7585.0
# Booking.com          4601.0
# Cisco                4100.0
# Peloton              4084.0
# Carvana              4000.0
# Better.com           3900.0
# Bytedance            3750.0
# Twitter              3700.0
# Groupon              3300.0

# %%
#companies = Sorted['company']
new = Sorted[0:10]
new.hvplot.bar(y='total_laid_off', height=500)
# Out:
# :Bars   [company]   (total_laid_off)

# %%
df.hvplot.scatter(x='total_laid_off', y='funds_raised', c='company')
